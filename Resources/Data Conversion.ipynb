# %%
import pandas as pd

# %%
#load file to read 
movie_data = "Merged_Frames.csv"

#read file 
movie_data_read = pd.read_csv(movie_data)

#make dataframe
movie_df = pd.DataFrame(movie_data_read)
movie_df.head()
# Out:
#        budget     revenue  popularity  production_companies  \
# 0  14000000.0  12314651.0    6.575393    Paramount Pictures
# 1  40000000.0  95149435.0    8.248895  Walt Disney Pictures
# 2   3300000.0  13092000.0   64.299990            Bold Films
# 3  14000000.0  85446075.0    7.286477  Ghost House Pictures
# 4         0.0  34327391.0    6.902423  Walt Disney Pictures
#
#        production_countries    imdb_id release_date  runtime    status  \
# 0  United States of America  tt2637294    2/20/2015     93.0  Released
# 1  United States of America  tt0368933     8/6/2004    113.0  Released
# 2  United States of America  tt2582802   10/10/2014    105.0  Released
# 3  United States of America  tt0431021    8/30/2012     92.0  Released
# 4  United States of America  tt0117110    2/16/1996    100.0  Released
#
#                                       title    genres
# 0                    Hot Tub Time Machine 2       NaN
# 1  The Princess Diaries 2: Royal Engagement     Drama
# ...

# %%
movie_html = movie_df.to_html()
print(movie_html)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>budget</th>
#       <th>revenue</th>
#       <th>popularity</th>
#       <th>production_companies</th>
#       <th>production_countries</th>
#       <th>imdb_id</th>
#       <th>release_date</th>
#       <th>runtime</th>
#       <th>status</th>
#       <th>title</th>
#       <th>genres</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>14000000.0</td>
#       <td>1.231465e+07</td>
#       <td>6.575393</td>
#       <td>Paramount Pictures</td>
#       <td>United States of America</td>
#       <td>tt2637294</td>
#       <td>2/20/2015</td>
#       <td>93.0</td>
#       <td>Released</td>
#       <td>Hot Tub Time Machine 2</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>40000000.0</td>
#       <td>9.514944e+07</td>
#       <td>8.248895</td>
#       <td>Walt Disney Pictures</td>
# ...
